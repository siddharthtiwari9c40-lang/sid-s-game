# %% [markdown]
# This notebook file contains a syllabus of applied calculus Lab
# **Limit of the function for one variable**
#
#
# *   definition of limit
# *  numerical experiment

# %%
2+3 # for sum
# Out:
# 5

# %%
2-3 # for substraction
# Out:
# -1

# %%
2*3 # for multiplication
# Out:
# 6

# %%
2**3 # for power use
# Out:
# 8

# %% [markdown]
# # Requirement for Calculus lab
#
#
# *   Numpy package or Library
# *   Matplotlib library
# *   Symbolic math library

# %%
x=3.9
print(x,type(x))
# Out:
# 3.9 <class 'float'>

# %% [markdown]
# # Numpy

# %%
import numpy as np # libbrary for numpy array
import numpy as np              # For numerical operations
import matplotlib.pyplot as plt # For plotting graphs
import math                     # For mathematical functions

# %%
a = np.array([1, 2, 3])  # Create a rank 1-D array
print(type(a), a.shape, a[0], a[1], a[2])
a[0] = 5                 # Change an element of the array
print(a)
# Out:
# <class 'numpy.ndarray'> (3,) 1 2 3
# [5 2 3]

# %%
b = np.array([[1,2,3],[4,5,6]])   # Create a 2D array
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
# Creating a list
values = [1, 2, 3, 4, 5]
print(values[0])  # Access first element (just like C)

# Creating a range
numbers = range(1, 6)  # Creates 1, 2, 3, 4, 5
# Out:
# 1

# %%
a = np.zeros((2,2))  # Create an array of all zeros
print(a)
# Out:
# [[0. 0.]
#  [0. 0.]]

# %%
b = np.ones((1,2))   # Create an array of all ones
print(b)
# Out:
# [[1. 1.]]

# %%
c = np.full((2,2), 7) # Create a constant array
print(c)
# Out:
# [[7 7]
#  [7 7]]

# %%
d = np.eye(2)        # Create a 2x2 identity matrix
print(d)
# Out:
# [[1. 0.]
#  [0. 1.]]

# %%
e = np.random.random((2,2)) # Create an array filled with random values
print(e)
# Out:
# [[0.51470662 0.95313097]
#  [0.22268081 0.34910344]]

# %%
x = np.array([[1,2],[3,4]])
y = np.array([[5,6],[7,8]])

# Elementwise sum; both produce the array
print(x + y)
print(np.add(x, y))
# Out:
# [[ 6  8]
#  [10 12]]
# [[ 6  8]
#  [10 12]]

# %%
# Elementwise difference; both produce the array
print(x - y)
print(np.subtract(x, y))
# Out:
# [[-4. -4.]
#  [-4. -4.]]
# [[-4. -4.]
#  [-4. -4.]]

# %%
# Elementwise division; both produce the array
# [[ 0.2         0.33333333]
#  [ 0.42857143  0.5       ]]
print(x / y)
print(np.divide(x, y))
# Out:
# [[0.2        0.33333333]
#  [0.42857143 0.5       ]]
# [[0.2        0.33333333]
#  [0.42857143 0.5       ]]

# %%
# Elementwise product; both produce the array
print(x * y)
print(np.multiply(x, y))
# Out:
# [[ 5. 12.]
#  [21. 32.]]
# [[ 5. 12.]
#  [21. 32.]]

# %% [markdown]
# # How to define function

# %%
def f1(x):              #Simple polynomial function
    return x**2 + 3*x - 1

# %%
def f2(x):              #Simple polynomial function
    return (x**2 -1)/(x**2+1)

# %%
f2(2)
# Out:
# 0.6

# %% [markdown]
# # Create a first graph

# %%
import matplotlib.pyplot as plt # for plot use

x = np.linspace(0, 2 * np.pi, 200)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %%
plt.plot(x,f1(x),'-r')
